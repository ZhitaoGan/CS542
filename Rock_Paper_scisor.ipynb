# %%
import pandas as pd
df = pd.read_csv('game_data.csv')

# %%
df
# Out:
#          you computer     result
# 0    Scissor  Scissor   We tied.
# 1    Scissor     Rock  You lost.
# 2      Paper     Rock   You won.
# 3    Scissor    Paper   You won.
# 4       Rock    Paper  You lost.
# 5    Scissor    Paper   You won.
# 6    Scissor  Scissor   We tied.
# 7      Paper  Scissor  You lost.
# 8    Scissor    Paper   You won.
# 9       Rock     Rock   We tied.
# 10   Scissor  Scissor   We tied.
# 11     Paper  Scissor  You lost.
# 12     Paper    Paper   We tied.
# 13      Rock    Paper  You lost.
# 14      Rock    Paper  You lost.
# 15     Paper    Paper   We tied.
# 16   Scissor  Scissor   We tied.
# 17     Paper  Scissor  You lost.
# 18      Rock    Paper  You lost.
# 19   Scissor  Scissor   We tied.
# 20   Scissor  Scissor   We tied.
# 21      Rock     Rock   We tied.
# 22     Paper  Scissor  You lost.
# 23   Scissor    Paper   You won.
# 24   Scissor    Paper   You won.
# 25     Paper     Rock   You won.
# 26     Paper     Rock   You won.
# ...

# %%
paper=len(df[df['computer']=='Paper'])/200
rock=len(df[df['computer']=='Rock'])/200
scissor=len(df[df['computer']=='Scissor'])/200

# %%
paper
# Out:
# 0.34

# %%
rock
# Out:
# 0.3

# %%
scissor
# Out:
# 0.36
